# %% [markdown]
# # Adaptive Distances

# %% [markdown]
# In this example, we show how and when to use the adaptive distances feature of pyabc. "Adaptive distances" means that the distance function is not pre-defined (e.g. after pre-processing), but evolves over time during the ABC run, depending on the observed summary statistics. This can be useful if different summary statistics vary on different scales, but it is not immediately clear how to weight them. For this case, in adaptive distances weights are adjusted in each iteration so as to balance the impact of all summary statistics on the computed distance.
#
# Currently, adaptively weighted p-norm distances (e.g. Euclidean) are implemented in pyABC, but it is easily possible to define arbitrary adaptive distances.

# %% [raw]
# The notebook can be downloaded :download:`here <adaptive_distances.ipynb>`.

# %% [markdown]
# For illustration, we consider a simple Gaussian model:

# %%
import numpy as np
import matplotlib.pyplot as pyplot
import pyabc
import logging

pyabc.settings.set_figure_params('pyabc')  # for beautified plots


# for debugging
df_logger = logging.getLogger('Distance')
df_logger.setLevel(logging.DEBUG)

# model definition
def model(p):
    return {'ss1': p['theta'] + 1 + 0.1 * np.random.normal(),
            'ss2': 2 + 10 * np.random.normal()}

# true model parameter
theta_true = 3

# observed summary statistics
observation = {'ss1': theta_true + 1, 'ss2': 2}

# prior distribution
prior = pyabc.Distribution(theta=pyabc.RV('uniform', 0, 10))

# database
db_path = pyabc.create_sqlite_db_id(file_="adaptive_distance.db")

# plotting

def plot_history(history):
    fig, ax = pyplot.subplots()
    for t in range(history.max_t + 1):
        df, w = history.get_distribution(m=0, t=t)
        pyabc.visualization.plot_kde_1d(df, w, xmin=0, xmax=10,
                                       x='theta', ax=ax,
                                       label="PDF t={}".format(t))
    ax.axvline(theta_true, color='k', linestyle='dashed', label="True value")
    ax.legend()

# %% [markdown]
# Summary statistic ss2 has a high variance compared to summary statistic ss1. In addition, ss1 is informative about the model parameters $\theta$, ss2 not. We expect that the proposal distribution for $\theta$ iteratively centers around the true value $\theta=3$. Thus, the variability for the sampled ss1 decreases iteratively, while the variability of the sampled ss2 stays approximately constant. If both summary statistics are weighted similarly in the calculation of the distance between sample and observation, there is hence an undesirable high impact of ss2, so that convergence can be slowed down. In contrast, if we weight ss1 higher, we may hope that our estimation of $\theta$ is improved.

# %% [markdown]
# These informal expectations being stated, let us continue with the implementation. First, we consider a non-adaptive Euclidean distance:

# %%
from sklearn.linear_model import LinearRegression

distance = pyabc.distance.InfoWeightedPNormDistance(predictor=LinearRegression(fit_intercept=False, normalize=False))

abc = pyabc.ABCSMC(
    model, prior, distance,
    acceptor = pyabc.UniformAcceptor(use_complete_history=True))

abc.new(db_path, observation)

history42 = abc.run(max_nr_populations=8, min_acceptance_rate=1e-2)

plot_history(history42)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=58, start_time=2021-03-25 16:55:28.532242>
# INFO:ABC:Calibration sample t=-1.
# DEBUG:Distance:Weights[0] = {'ss1': 0.9964371696997772, 'ss2': 0.0035628303002227238}
# INFO:Epsilon:initial epsilon is 2.613495790612617
# INFO:Population:Recording also rejected particles: True
# INFO:ABC:t: 0, eps: 2.613495790612617.
# INFO:ABC:Acceptance rate: 100 / 200 = 5.0000e-01, ESS=1.0000e+02.
# DEBUG:Distance:Weights[1] = {'ss1': 0.9970233173773784, 'ss2': 0.0029766826226216444}
# INFO:ABC:t: 1, eps: 1.209656075682004.
# INFO:ABC:Acceptance rate: 100 / 206 = 4.8544e-01, ESS=9.8466e+01.
# DEBUG:Distance:Weights[2] = {'ss1': 0.9999031634357723, 'ss2': 9.683656422769428e-05}
# INFO:ABC:t: 2, eps: 0.6212643963205932.
# INFO:ABC:Acceptance rate: 100 / 187 = 5.3476e-01, ESS=9.9974e+01.
# DEBUG:Distance:Weights[3] = {'ss1': 0.9864293900167516, 'ss2': 0.013570609983248435}
# INFO:ABC:t: 3, eps: 0.33208818860989764.
# INFO:ABC:Acceptance rate: 100 / 202 = 4.9505e-01, ESS=9.8509e+01.
# DEBUG:Distance:Weights[4] = {'ss1': 0.9762259512771095, 'ss2': 0.023774048722890417}
# INFO:ABC:t: 4, eps: 0.2765895716745046.
# INFO:ABC:Acceptance rate: 100 / 214 = 4.6729e-01, ESS=9.6988e+01.
# DEBUG:Distance:Weights[5] = {'ss1': 0.9409631959684428, 'ss2': 0.05903680403155715}
# INFO:ABC:t: 5, eps: 0.3299360461727064.
# INFO:ABC:Acceptance rate: 100 / 312 = 3.2051e-01, ESS=9.0009e+01.
# DEBUG:Distance:Weights[6] = {'ss1': 0.9702100569581251, 'ss2': 0.02978994304187488}
# INFO:ABC:t: 6, eps: 0.13870327224743426.
# INFO:ABC:Acceptance rate: 100 / 717 = 1.3947e-01, ESS=9.6484e+01.
# DEBUG:Distance:Weights[7] = {'ss1': 0.9993468840825062, 'ss2': 0.0006531159174938116}
# INFO:ABC:t: 7, eps: 0.05045337361376912.
# INFO:ABC:Acceptance rate: 100 / 1204 = 8.3056e-02, ESS=8.6855e+01.
# DEBUG:Distance:Weights[8] = {'ss1': 0.941659047953693, 'ss2': 0.05834095204630695}
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=58, duration=0:00:07.299577, end_time=2021-03-25 16:55:35.831819>

# %%
distance = pyabc.AdaptivePNormDistance(sumstat=pyabc.GPPredictorSumstat(adaptive=True))

abc = pyabc.ABCSMC(
    model, prior, distance,
    acceptor = pyabc.UniformAcceptor(use_complete_history=True))

abc.new(db_path, observation)

history42 = abc.run(max_nr_populations=8, min_acceptance_rate=1e-2)

plot_history(history42)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=45, start_time=2021-03-25 16:39:24.318967>
# INFO:ABC:Calibration sample t=-1.
# DEBUG:Distance:Weights[0] = {'S_0': 1.0005956289267033}
# INFO:Epsilon:initial epsilon is 0.911577533266357
# INFO:Population:Recording also rejected particles: True
# INFO:Population:Recording also rejected particles: True
# INFO:ABC:t: 0, eps: 0.911577533266357.
# INFO:ABC:Acceptance rate: 100 / 224 = 4.4643e-01, ESS=1.0000e+02.
# /home/yannik/anaconda3/envs/env/lib/python3.9/site-packages/sklearn/gaussian_process/kernels.py:402: ConvergenceWarning: The optimal value found for dimension 0 of parameter k1__sigma_0 is close to the specified lower bound 1e-05. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn("The optimal value found for "
# DEBUG:Distance:Weights[1] = {'S_0': 1.0006636211427042}
# INFO:ABC:t: 1, eps: 0.44939383157534096.
# INFO:ABC:Acceptance rate: 100 / 178 = 5.6180e-01, ESS=9.9785e+01.
# DEBUG:Distance:Weights[2] = {'S_0': 1.002536490978794}
# INFO:ABC:t: 2, eps: 0.4033918063095018.
# INFO:ABC:Acceptance rate: 100 / 214 = 4.6729e-01, ESS=9.9026e+01.
# DEBUG:Distance:Weights[3] = {'S_0': 1.0058883869094548}
# INFO:ABC:t: 3, eps: 0.3851837903250274.
# INFO:ABC:Acceptance rate: 100 / 168 = 5.9524e-01, ESS=9.6838e+01.
# DEBUG:Distance:Weights[4] = {'S_0': 1.0355004160993742}
# INFO:ABC:t: 4, eps: 0.46018712489473773.
# INFO:ABC:Acceptance rate: 100 / 252 = 3.9683e-01, ESS=9.8625e+01.
# DEBUG:Distance:Weights[5] = {'S_0': 1.0812078074979985}
# INFO:ABC:t: 5, eps: 0.28944684580183583.
# INFO:ABC:Acceptance rate: 100 / 397 = 2.5189e-01, ESS=8.1247e+01.
# DEBUG:Distance:Weights[6] = {'S_0': 1.1723098147285136}
# INFO:ABC:t: 6, eps: 0.19303520911412367.
# INFO:ABC:Acceptance rate: 100 / 612 = 1.6340e-01, ESS=9.2795e+01.
# DEBUG:Distance:Weights[7] = {'S_0': 1.308777737567971}
# INFO:ABC:t: 7, eps: 0.10740236578596546.
# INFO:ABC:Acceptance rate: 100 / 931 = 1.0741e-01, ESS=7.7050e+01.
# DEBUG:Distance:Weights[8] = {'S_0': 1.4584342688527754}
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=45, duration=0:00:17.793519, end_time=2021-03-25 16:39:42.112486>

# %%
distance = pyabc.AdaptivePNormDistance(sumstat=pyabc.LinearPredictorSumstat(adaptive=True))

abc = pyabc.ABCSMC(
    model, prior, distance,
    acceptor = pyabc.UniformAcceptor(use_complete_history=True))

abc.new(db_path, observation)

history42 = abc.run(max_nr_populations=8)

plot_history(history42)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=46, start_time=2021-03-25 16:40:23.023681>
# INFO:ABC:Calibration sample t=-1.
# DEBUG:Distance:Weights[0] = {'S_0': 1.0005368189595256}
# INFO:Epsilon:initial epsilon is 0.8626846779455013
# INFO:Population:Recording also rejected particles: True
# INFO:Population:Recording also rejected particles: True
# INFO:ABC:t: 0, eps: 0.8626846779455013.
# INFO:ABC:Acceptance rate: 100 / 216 = 4.6296e-01, ESS=1.0000e+02.
# DEBUG:Distance:Weights[1] = {'S_0': 1.0005825106589101}
# INFO:ABC:t: 1, eps: 0.4734414298752078.
# INFO:ABC:Acceptance rate: 100 / 183 = 5.4645e-01, ESS=9.9613e+01.
# DEBUG:Distance:Weights[2] = {'S_0': 1.001832789267093}
# INFO:ABC:t: 2, eps: 0.4361312556576521.
# INFO:ABC:Acceptance rate: 100 / 200 = 5.0000e-01, ESS=9.8294e+01.
# DEBUG:Distance:Weights[3] = {'S_0': 1.0060848510630873}
# INFO:ABC:t: 3, eps: 0.4470399934598196.
# INFO:ABC:Acceptance rate: 100 / 221 = 4.5249e-01, ESS=9.9392e+01.
# DEBUG:Distance:Weights[4] = {'S_0': 1.0234051631634027}
# INFO:ABC:t: 4, eps: 0.42053587466324627.
# INFO:ABC:Acceptance rate: 100 / 231 = 4.3290e-01, ESS=9.9111e+01.
# DEBUG:Distance:Weights[5] = {'S_0': 1.0646610212224281}
# INFO:ABC:t: 5, eps: 0.3626483992745641.
# INFO:ABC:Acceptance rate: 100 / 243 = 4.1152e-01, ESS=8.1213e+01.
# DEBUG:Distance:Weights[6] = {'S_0': 1.1527137536457395}
# INFO:ABC:t: 6, eps: 0.28967041726674664.
# INFO:ABC:Acceptance rate: 100 / 368 = 2.7174e-01, ESS=6.6833e+01.
# DEBUG:Distance:Weights[7] = {'S_0': 1.2307614766367974}
# INFO:ABC:t: 7, eps: 0.19293731916970172.
# INFO:ABC:Acceptance rate: 100 / 695 = 1.4388e-01, ESS=9.1973e+01.
# DEBUG:Distance:Weights[8] = {'S_0': 1.2251565577295838}
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=46, duration=0:00:05.415067, end_time=2021-03-25 16:40:28.438748>

# %%
distance = pyabc.PNormDistance(sumstat=pyabc.LinearPredictorSumstat(adaptive=True))

abc = pyabc.ABCSMC(
    model, prior, distance,
    acceptor = pyabc.UniformAcceptor(use_complete_history=True))

abc.new(db_path, observation)

history43 = abc.run(max_nr_populations=8)

plot_history(history43)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=47, start_time=2021-03-25 16:41:28.764259>
# INFO:ABC:Calibration sample t=-1.
# INFO:Epsilon:initial epsilon is 0.6945281662617674
# INFO:Population:Recording also rejected particles: True
# INFO:ABC:t: 0, eps: 0.6945281662617674.
# INFO:ABC:Acceptance rate: 100 / 261 = 3.8314e-01, ESS=1.0000e+02.
# INFO:ABC:t: 1, eps: 0.35666459409711737.
# INFO:ABC:Acceptance rate: 100 / 197 = 5.0761e-01, ESS=9.9751e+01.
# INFO:ABC:t: 2, eps: 0.40451796128156264.
# INFO:ABC:Acceptance rate: 100 / 248 = 4.0323e-01, ESS=9.9939e+01.
# INFO:ABC:t: 3, eps: 0.3314573420164387.
# INFO:ABC:Acceptance rate: 100 / 221 = 4.5249e-01, ESS=8.8833e+01.
# INFO:ABC:t: 4, eps: 0.3447305461204092.
# INFO:ABC:Acceptance rate: 100 / 249 = 4.0161e-01, ESS=9.3513e+01.
# INFO:ABC:t: 5, eps: 0.2799937482048817.
# INFO:ABC:Acceptance rate: 100 / 334 = 2.9940e-01, ESS=6.5689e+01.
# INFO:ABC:t: 6, eps: 0.15604503311091839.
# INFO:ABC:Acceptance rate: 100 / 635 = 1.5748e-01, ESS=4.6503e+01.
# INFO:ABC:t: 7, eps: 0.0909614743462064.
# INFO:ABC:Acceptance rate: 100 / 1312 = 7.6220e-02, ESS=8.3835e+01.
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=47, duration=0:00:05.203545, end_time=2021-03-25 16:41:33.967804>

# %%
distance = pyabc.PNormDistance(p=2)

abc = pyabc.ABCSMC(model, prior, distance)

abc.new(db_path, observation)

history0 = abc.run(minimum_epsilon=.1, max_nr_populations=8)

plot_history(history0)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=48, start_time=2021-03-25 16:41:40.209032>
# INFO:ABC:Calibration sample t=-1.
# INFO:Epsilon:initial epsilon is 7.9217637212244725
# INFO:ABC:t: 0, eps: 7.9217637212244725.
# INFO:ABC:Acceptance rate: 100 / 208 = 4.8077e-01, ESS=1.0000e+02.
# INFO:ABC:t: 1, eps: 5.0238890456352046.
# INFO:ABC:Acceptance rate: 100 / 370 = 2.7027e-01, ESS=9.7758e+01.
# INFO:ABC:t: 2, eps: 3.2612879841686313.
# INFO:ABC:Acceptance rate: 100 / 528 = 1.8939e-01, ESS=9.3216e+01.
# INFO:ABC:t: 3, eps: 2.2339040983705196.
# INFO:ABC:Acceptance rate: 100 / 990 = 1.0101e-01, ESS=9.9496e+01.
# INFO:ABC:t: 4, eps: 1.4355407176251478.
# INFO:ABC:Acceptance rate: 100 / 1479 = 6.7613e-02, ESS=9.5532e+01.
# INFO:ABC:t: 5, eps: 0.9546209376439954.
# INFO:ABC:Acceptance rate: 100 / 1932 = 5.1760e-02, ESS=9.6255e+01.
# INFO:ABC:t: 6, eps: 0.7022395249650646.
# INFO:ABC:Acceptance rate: 100 / 3293 = 3.0367e-02, ESS=9.7695e+01.
# INFO:ABC:t: 7, eps: 0.48944812475879573.
# INFO:ABC:Acceptance rate: 100 / 4174 = 2.3958e-02, ESS=9.5742e+01.
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=48, duration=0:00:09.996049, end_time=2021-03-25 16:41:50.205081>

# %%
distance_adaptive = pyabc.AdaptivePNormDistance(p=2, adaptive=False)

abc = pyabc.ABCSMC(
    model, prior, distance_adaptive,
    acceptor = pyabc.UniformAcceptor(use_complete_history=True))

abc.new(db_path, observation)

history30 = abc.run(minimum_epsilon=.1, max_nr_populations=8)

plot_history(history30)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=50, start_time=2021-03-25 16:42:20.643614>
# INFO:ABC:Calibration sample t=-1.
# DEBUG:Distance:Weights[0] = {'ss1': 0.3284530669777326, 'ss2': 0.094336192437848}
# INFO:Epsilon:initial epsilon is 1.3399110581713856
# INFO:ABC:t: 0, eps: 1.3399110581713856.
# INFO:ABC:Acceptance rate: 100 / 204 = 4.9020e-01, ESS=1.0000e+02.
# INFO:ABC:t: 1, eps: 0.872209957722555.
# INFO:ABC:Acceptance rate: 100 / 214 = 4.6729e-01, ESS=9.6594e+01.
# INFO:ABC:t: 2, eps: 0.6693698299184107.
# INFO:ABC:Acceptance rate: 100 / 263 = 3.8023e-01, ESS=9.4645e+01.
# INFO:ABC:t: 3, eps: 0.4537495179917504.
# INFO:ABC:Acceptance rate: 100 / 348 = 2.8736e-01, ESS=9.3185e+01.
# INFO:ABC:t: 4, eps: 0.33727498559981106.
# INFO:ABC:Acceptance rate: 100 / 554 = 1.8051e-01, ESS=9.4170e+01.
# INFO:ABC:t: 5, eps: 0.23485919915342487.
# INFO:ABC:Acceptance rate: 100 / 848 = 1.1792e-01, ESS=9.6270e+01.
# INFO:ABC:t: 6, eps: 0.1753292443084851.
# INFO:ABC:Acceptance rate: 100 / 998 = 1.0020e-01, ESS=8.9717e+01.
# INFO:ABC:t: 7, eps: 0.12132322802735422.
# INFO:ABC:Acceptance rate: 100 / 1695 = 5.8997e-02, ESS=9.5790e+01.
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=50, duration=0:00:05.781546, end_time=2021-03-25 16:42:26.425160>

# %%
distance_adaptive = pyabc.AdaptivePNormDistance(p=2)

abc = pyabc.ABCSMC(
    model, prior, distance_adaptive,
    acceptor = pyabc.UniformAcceptor(use_complete_history=True))

abc.new(db_path, observation)

history1 = abc.run(minimum_epsilon=.1, max_nr_populations=8)

plot_history(history1)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=51, start_time=2021-03-25 16:42:33.670253>
# INFO:ABC:Calibration sample t=-1.
# DEBUG:Distance:Weights[0] = {'ss1': 0.35556069230113235, 'ss2': 0.11676253503985992}
# INFO:Epsilon:initial epsilon is 1.493794461722129
# INFO:Population:Recording also rejected particles: True
# INFO:ABC:t: 0, eps: 1.493794461722129.
# INFO:ABC:Acceptance rate: 100 / 213 = 4.6948e-01, ESS=1.0000e+02.
# DEBUG:Distance:Weights[1] = {'ss1': 0.3353442697681934, 'ss2': 0.10153232308298468}
# INFO:ABC:t: 1, eps: 0.855418405951523.
# INFO:ABC:Acceptance rate: 100 / 270 = 3.7037e-01, ESS=9.9409e+01.
# DEBUG:Distance:Weights[2] = {'ss1': 0.5209462589795923, 'ss2': 0.09519005918629907}
# INFO:ABC:t: 2, eps: 0.7663963297786303.
# INFO:ABC:Acceptance rate: 100 / 272 = 3.6765e-01, ESS=9.9661e+01.
# DEBUG:Distance:Weights[3] = {'ss1': 0.7098379931698814, 'ss2': 0.10637797718046507}
# INFO:ABC:t: 3, eps: 0.6352164293638517.
# INFO:ABC:Acceptance rate: 100 / 308 = 3.2468e-01, ESS=9.7079e+01.
# DEBUG:Distance:Weights[4] = {'ss1': 1.3565880035043558, 'ss2': 0.1028637966659866}
# INFO:ABC:t: 4, eps: 0.6305640738946893.
# INFO:ABC:Acceptance rate: 100 / 461 = 2.1692e-01, ESS=9.9429e+01.
# DEBUG:Distance:Weights[5] = {'ss1': 1.9122507488354472, 'ss2': 0.09941560826396857}
# INFO:ABC:t: 5, eps: 0.5566065942327567.
# INFO:ABC:Acceptance rate: 100 / 489 = 2.0450e-01, ESS=9.6362e+01.
# DEBUG:Distance:Weights[6] = {'ss1': 3.2074511278659776, 'ss2': 0.10098112556464911}
# INFO:ABC:t: 6, eps: 0.5095218618542514.
# INFO:ABC:Acceptance rate: 100 / 650 = 1.5385e-01, ESS=9.5578e+01.
# DEBUG:Distance:Weights[7] = {'ss1': 4.295449840724099, 'ss2': 0.1038497068330713}
# INFO:ABC:t: 7, eps: 0.423875668033393.
# INFO:ABC:Acceptance rate: 100 / 965 = 1.0363e-01, ESS=8.3641e+01.
# DEBUG:Distance:Weights[8] = {'ss1': 6.749138108327539, 'ss2': 0.09928532973814164}
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=51, duration=0:00:05.108227, end_time=2021-03-25 16:42:38.778480>

# %% [markdown]
# We observe differences compared to the non-adaptive setting. In particular, the densitities tend to be narrower around the true parameter $\theta=3$. In addition, despite the better convergence, the required number of samples in total is lower, as not so much time was wasted trying to match an uninformative summary statistic:

# %%
histories = [history0, history30, history1, history42, history43]
labels = ["Fixed distance", "Tuned distance", "Adaptive distance", "Britney", "Adaptive britney"]
pyabc.visualization.plot_sample_numbers(histories, labels, rotation=45)
# Out:
# <AxesSubplot:title={'center':'Required samples'}, xlabel='Run', ylabel='Samples'>

# %% [markdown]
# Indeed, the acceptance rates for the adaptive distance function are continually higher:

# %%
pyabc.visualization.plot_acceptance_rates_trajectory(histories, labels)
# Out:
# <AxesSubplot:title={'center':'Acceptance rates'}, xlabel='Population index $t$', ylabel='Acceptance rate'>

# %% [markdown]
# In detail, the adaptive distance feature works as follows: In each iteration of the ABCSMC run, after having obtained the desired number of accepted particles (and once at the beginning using a sample from the prior), the method ``DistanceFunction.update()`` is called. It is given a set of summary statistics which can be used to e.g. compute weights for the distance measure in the next iteration. In order to avoid bias, via ``DistanceFunction.configure_sampler()``, the distance function can tell the sampler to not only record accepted particles, but all that were generated during the sampling process.
# So, when you want to define your own adaptive distance function, you will typically only need to overwrite these two methods. For implementation details and an example of how this can look in practice, please inspect the code of ``AdaptivePNormDistance``.

# %% [markdown]
# ## Make it robust
#
# A problem with the previous adaptive distance occurs when the weights do not work properly. For instance, there could be large weights assigned to rather non-informative statistics, if these vary comparably little. Let us have a look at an example:

# %%
import numpy as np
import tempfile
import os
import matplotlib.pyplot as pyplot
import pyabc.visualization
import logging


# for debugging
df_logger = logging.getLogger('Distance')
df_logger.setLevel(logging.DEBUG)

# model definition
def model(p):
    return {'ss1': p['theta'] + 1 + 1 * np.random.normal(),
            'ss2': 2 + 0.01 * np.random.normal()}

# true model parameter
theta_true = 3

# observed summary statistics
observation = {'ss1': theta_true + 1, 'ss2': 5}

# prior distribution
prior = pyabc.Distribution(theta=pyabc.RV('uniform', 0, 10))

# database
db_path = pyabc.create_sqlite_db_id(file_="adaptive_distance.db")


# plotting

def plot_history(history):
    fig, ax = pyplot.subplots()
    for t in range(history.max_t + 1):
        df, w = history.get_distribution(m=0, t=t)
        pyabc.visualization.plot_kde_1d(df, w, xmin=0, xmax=10,
                                       x='theta', ax=ax,
                                       label="PDF t={}".format(t))
    ax.axvline(theta_true, color='k', linestyle='dashed', label="True value")
    ax.legend()

# %% [markdown]
# Essentially, we changed the variances of the two summary statistics, and in addition we shifted the observed value `ss2` to 5, which can be interpreted as a measurement error. Now the problem is that this value is highly unlikely to sample from under the model, and when using adaptive weights, this statistic might due to the small variance be assigned a high weight, worsening the problem.

# %%
distance = pyabc.PNormDistance(p=2)

abc = pyabc.ABCSMC(model, prior, distance)
abc.new(db_path, observation)
history0 = abc.run(minimum_epsilon=.001, max_nr_populations=5)

plot_history(history0)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=59, start_time=2021-03-25 17:01:47.153417>
# INFO:ABC:Calibration sample t=-1.
# INFO:Epsilon:initial epsilon is 3.8660419688538936
# INFO:ABC:t: 0, eps: 3.8660419688538936.
# INFO:ABC:Acceptance rate: 100 / 201 = 4.9751e-01, ESS=1.0000e+02.
# INFO:ABC:t: 1, eps: 3.168829652672515.
# INFO:ABC:Acceptance rate: 100 / 279 = 3.5842e-01, ESS=9.5986e+01.
# INFO:ABC:t: 2, eps: 3.0410533906010633.
# INFO:ABC:Acceptance rate: 100 / 413 = 2.4213e-01, ESS=8.6091e+01.
# INFO:ABC:t: 3, eps: 3.014031296153611.
# INFO:ABC:Acceptance rate: 100 / 653 = 1.5314e-01, ESS=9.5234e+01.
# INFO:ABC:t: 4, eps: 3.0027326577553843.
# INFO:ABC:Acceptance rate: 100 / 1321 = 7.5700e-02, ESS=5.9965e+01.
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=59, duration=0:00:03.326917, end_time=2021-03-25 17:01:50.480334>

# %%
distance_adaptive = pyabc.AdaptivePNormDistance(p=2)

abc = pyabc.ABCSMC(
    model, prior, distance_adaptive,
    acceptor = pyabc.UniformAcceptor(use_complete_history=True))
abc.new(db_path, observation)
history1 = abc.run(minimum_epsilon=.001, max_nr_populations=5)

plot_history(history1)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=60, start_time=2021-03-25 17:01:53.889749>
# INFO:ABC:Calibration sample t=-1.
# DEBUG:Distance:Weights[0] = {'ss1': 0.3506032780626231, 'ss2': 106.0102107979052}
# INFO:Epsilon:initial epsilon is 317.9651352440293
# INFO:Population:Recording also rejected particles: True
# INFO:ABC:t: 0, eps: 317.9651352440293.
# INFO:ABC:Acceptance rate: 100 / 200 = 5.0000e-01, ESS=1.0000e+02.
# DEBUG:Distance:Weights[1] = {'ss1': 0.33150709782128246, 'ss2': 103.13016633361742}
# INFO:ABC:t: 1, eps: 308.70265017868417.
# INFO:ABC:Acceptance rate: 100 / 358 = 2.7933e-01, ESS=9.6277e+01.
# DEBUG:Distance:Weights[2] = {'ss1': 0.33299982509442255, 'ss2': 103.24656094598268}
# INFO:ABC:t: 2, eps: 308.70638015615356.
# INFO:ABC:Acceptance rate: 100 / 708 = 1.4124e-01, ESS=9.0631e+01.
# DEBUG:Distance:Weights[3] = {'ss1': 0.3399578670544385, 'ss2': 101.9602044159181}
# INFO:ABC:t: 3, eps: 304.5197584615693.
# INFO:ABC:Acceptance rate: 100 / 1103 = 9.0662e-02, ESS=9.8156e+01.
# DEBUG:Distance:Weights[4] = {'ss1': 0.33951338429605227, 'ss2': 101.7372790649734}
# INFO:ABC:t: 4, eps: 303.43706835450274.
# INFO:ABC:Acceptance rate: 100 / 2493 = 4.0112e-02, ESS=9.4980e+01.
# DEBUG:Distance:Weights[5] = {'ss1': 0.36421273576708685, 'ss2': 101.05931138339943}
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=60, duration=0:00:04.359014, end_time=2021-03-25 17:01:58.248763>

# %% [markdown]
# These results are as expected: The adaptive weights make the situation much worse. Our solution is to in addition to the in-sample variance also take the bias of the samples to the observed data into account, using e.g. the `root_mean_square_deviation` as scale function.

# %%
distance_adaptive = pyabc.AdaptivePNormDistance(
    p=2, scale_function=pyabc.distance.root_mean_square_deviation)

abc = pyabc.ABCSMC(
    model, prior, distance_adaptive,
    acceptor = pyabc.UniformAcceptor(use_complete_history=True))
abc.new(db_path, observation)
history2 = abc.run(minimum_epsilon=.001, max_nr_populations=5)

plot_history(history2)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=61, start_time=2021-03-25 17:02:01.731526>
# INFO:ABC:Calibration sample t=-1.
# DEBUG:Distance:Weights[0] = {'ss1': 0.2613463104028677, 'ss2': 0.3332985228019408}
# INFO:Epsilon:initial epsilon is 1.3367681018150324
# INFO:Population:Recording also rejected particles: True
# INFO:ABC:t: 0, eps: 1.3367681018150324.
# INFO:ABC:Acceptance rate: 100 / 161 = 6.2112e-01, ESS=1.0000e+02.
# DEBUG:Distance:Weights[1] = {'ss1': 0.25815749632182733, 'ss2': 0.333390345516811}
# INFO:ABC:t: 1, eps: 1.0967624444700985.
# INFO:ABC:Acceptance rate: 100 / 203 = 4.9261e-01, ESS=9.7115e+01.
# DEBUG:Distance:Weights[2] = {'ss1': 0.4269258873120388, 'ss2': 0.33342931483193333}
# INFO:ABC:t: 2, eps: 1.0705181166560567.
# INFO:ABC:Acceptance rate: 100 / 260 = 3.8462e-01, ESS=9.3263e+01.
# DEBUG:Distance:Weights[3] = {'ss1': 0.561405482113559, 'ss2': 0.33334855015892156}
# INFO:ABC:t: 3, eps: 1.021168133702136.
# INFO:ABC:Acceptance rate: 100 / 541 = 1.8484e-01, ESS=7.2112e+01.
# DEBUG:Distance:Weights[4] = {'ss1': 0.6614492212325277, 'ss2': 0.3333629098072651}
# INFO:ABC:t: 4, eps: 1.0068228997119806.
# INFO:ABC:Acceptance rate: 100 / 1034 = 9.6712e-02, ESS=7.5411e+01.
# DEBUG:Distance:Weights[5] = {'ss1': 0.6766520653876942, 'ss2': 0.3333377439346521}
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=61, duration=0:00:02.939169, end_time=2021-03-25 17:02:04.670695>

# %%
distance = pyabc.PNormDistance(sumstat=pyabc.LinearPredictorSumstat(adaptive=False))
#distance = pyabc.PNormDistance(sumstat=pyabc.GPPredictorSumstat())
#distance = pyabc.britney.AdaptiveEuclidean(pyabc.britney.PredictorBritney(predictor=gp_predictor), adaptive=True)

abc = pyabc.ABCSMC(
    model, prior, distance, population_size=100,
    acceptor = pyabc.UniformAcceptor(use_complete_history=True))
abc.new(db_path, observation)
history2 = abc.run(min_acceptance_rate=0.01, max_nr_populations=4)

plot_history(history2)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=65, start_time=2021-03-25 17:04:41.038180>
# INFO:ABC:Calibration sample t=-1.
# INFO:Epsilon:initial epsilon is 7.637114503516454
# INFO:ABC:t: 0, eps: 7.637114503516454.
# INFO:ABC:Acceptance rate: 100 / 215 = 4.6512e-01, ESS=1.0000e+02.
# INFO:ABC:t: 1, eps: 6.753931382614823.
# INFO:ABC:Acceptance rate: 100 / 252 = 3.9683e-01, ESS=9.5415e+01.
# INFO:ABC:t: 2, eps: 6.416316050236253.
# INFO:ABC:Acceptance rate: 100 / 236 = 4.2373e-01, ESS=9.3691e+01.
# INFO:ABC:t: 3, eps: 6.2174340013757154.
# INFO:ABC:Acceptance rate: 100 / 502 = 1.9920e-01, ESS=9.7920e+01.
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=65, duration=0:00:02.329119, end_time=2021-03-25 17:04:43.367299>

# %%
from sklearn.linear_model import LinearRegression

distance = pyabc.distance.InfoWeightedPNormDistance(predictor=LinearRegression(fit_intercept=False, normalize=False))

abc = pyabc.ABCSMC(
    model, prior, distance)

abc.new(db_path, observation)

history42 = abc.run(max_nr_populations=8, min_acceptance_rate=1e-2)

plot_history(history42)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=66, start_time=2021-03-25 17:05:19.426697>
# INFO:ABC:Calibration sample t=-1.
# DEBUG:Distance:Weights[0] = {'ss1': 0.9936503795785456, 'ss2': 0.006349620421454423}
# INFO:Epsilon:initial epsilon is 2.604895099640039
# INFO:Population:Recording also rejected particles: True
# INFO:ABC:t: 0, eps: 2.604895099640039.
# INFO:ABC:Acceptance rate: 100 / 217 = 4.6083e-01, ESS=1.0000e+02.
# DEBUG:Distance:Weights[1] = {'ss1': 0.992604079601063, 'ss2': 0.007395920398936945}
# INFO:ABC:t: 1, eps: 1.2110099661807585.
# INFO:ABC:Acceptance rate: 100 / 234 = 4.2735e-01, ESS=9.1321e+01.
# DEBUG:Distance:Weights[2] = {'ss1': 0.9922965214545486, 'ss2': 0.007703478545451429}
# INFO:ABC:t: 2, eps: 0.520960800332098.
# INFO:ABC:Acceptance rate: 100 / 410 = 2.4390e-01, ESS=9.4066e+01.
# DEBUG:Distance:Weights[3] = {'ss1': 0.9701207907137644, 'ss2': 0.029879209286235598}
# INFO:ABC:t: 3, eps: 0.2934465236715714.
# INFO:ABC:Acceptance rate: 100 / 611 = 1.6367e-01, ESS=6.1978e+01.
# DEBUG:Distance:Weights[4] = {'ss1': 0.9306570149723855, 'ss2': 0.0693429850276145}
# INFO:ABC:t: 4, eps: 0.23733615540860328.
# INFO:ABC:Acceptance rate: 100 / 1501 = 6.6622e-02, ESS=8.2382e+01.
# DEBUG:Distance:Weights[5] = {'ss1': 0.9840598335375563, 'ss2': 0.01594016646244367}
# INFO:ABC:t: 5, eps: 0.07165222910587993.
# INFO:ABC:Acceptance rate: 100 / 3700 = 2.7027e-02, ESS=8.8471e+01.
# DEBUG:Distance:Weights[6] = {'ss1': 0.9881632236114013, 'ss2': 0.01183677638859871}
# INFO:ABC:t: 6, eps: 0.0421916284741077.
# INFO:ABC:Acceptance rate: 100 / 6894 = 1.4505e-02, ESS=7.7276e+01.
# DEBUG:Distance:Weights[7] = {'ss1': 0.9903049594262766, 'ss2': 0.0096950405737234}
# INFO:ABC:t: 7, eps: 0.031609466421482164.
# INFO:ABC:Acceptance rate: 100 / 15861 = 6.3048e-03, ESS=8.6691e+01.
# DEBUG:Distance:Weights[8] = {'ss1': 0.9952258997882644, 'ss2': 0.004774100211735659}
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=66, duration=0:00:16.121026, end_time=2021-03-25 17:05:35.547723>

# %% [markdown]
# In this setting, the accuracy and sample numbers (see below) are rougly back to the non-weighted case. Applying this method to the first model shows that it is also applicable there, though potentially slightly less efficient. This demonstrates that this method is more robust in taking model error into account, which in practice can easily occur.

# %%
pyabc.visualization.plot_sample_numbers([history0, history1, history2], ["Fixed distance", "Adaptive", "Robust adaptive"])
# Out:
# <AxesSubplot:title={'center':'Required samples'}, xlabel='Run', ylabel='Samples'>

# %% [markdown]
# ## Weight diverse data with replicates

# %% [markdown]
# The problem we consider now is that we can separate our summary statistics (=data) into subsets which are informative for different parameters, but the sizes of these subsets are not balanced. This happens frequently in practice, e.g. when one has a time series of 100 measurements, compared to a single data point. If these two statistics are informative for different parameters, then the impact of the first kind on the computed distance value can be overly high, and in addition the automatic weighting as introduced by Prangle 2017 may not reduce, or can indeed even worsen, the problem.
#
# Thus, what we want to do is add additional "factors" by which we multiply each data point's weight. These factors take into account the number of summary statistics that are equally informative. At the moment, these factors still need to be defined manually.

# %% [markdown]
# Let us consider a toy model, where we just copy a single summary statistic N0=100 times. Note that this model is highly artificical, as in practise there might be more information contained in e.g. a time series than in a single measurement, but not N0 times as much, such that a good factor would be somewhere between 1 and N0.

# %%
import pyabc
import numpy as np
import os
import tempfile
import matplotlib.pyplot as plt
import logging

# for debugging
df_logger = logging.getLogger('Distance')
df_logger.setLevel(logging.DEBUG)

N0 = 100
N1 = 1

p_true = {'p0': 5, 'p1': 10}

def model(p):
    ss = {}
    s0 = p['p0'] + 2 * np.random.normal()
    for j in range(N0):
        ss['p0_' + str(j)] = s0
    s1 = p['p1'] + 0.01 * np.random.normal()
    for j in range(N1):
        ss['p1_' + str(j)] = s1
    return ss

prior = pyabc.Distribution(p0=pyabc.RV("uniform", 0, 20),
                           p1=pyabc.RV("uniform", 0, 20))

observation = model(p_true)

# plotting

def plot_history(history):
    fig, ax = plt.subplots()
    for t in range(history.max_t + 1):
        df, w = history.get_distribution(m=0, t=t)
        pyabc.visualization.plot_kde_1d(df, w, xmin=0, xmax=20,
                                        x='p0', ax=ax,
                                        label="PDF t={}".format(t),
                                        refval=p_true)
    ax.legend()

    fig, ax = plt.subplots()
    for t in range(history.max_t + 1):
        df, w = history.get_distribution(m=0, t=t)
        pyabc.visualization.plot_kde_1d(df, w, xmin=0, xmax=20,
                                        x='p1', ax=ax,
                                        label="PDF t={}".format(t),
                                        refval=p_true)
    ax.legend()

# %% [markdown]
# First, we consider uniform weights of 1:

# %%
distance = pyabc.PNormDistance(p=1)

abc = pyabc.ABCSMC(model, prior, distance)

db_path = pyabc.create_sqlite_db_id(file_="adaptive_distance.db")
abc.new(db_path, observation)
history1 = abc.run(max_nr_populations=8)

plot_history(history1)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=67, start_time=2021-03-25 17:06:26.531182>
# INFO:ABC:Calibration sample t=-1.
# INFO:Epsilon:initial epsilon is 427.36011721705034
# INFO:ABC:t: 0, eps: 427.36011721705034.
# INFO:ABC:Acceptance rate: 100 / 246 = 4.0650e-01, ESS=1.0000e+02.
# INFO:ABC:t: 1, eps: 207.03762136330292.
# INFO:ABC:Acceptance rate: 100 / 269 = 3.7175e-01, ESS=8.9405e+01.
# INFO:ABC:t: 2, eps: 91.44989840882408.
# INFO:ABC:Acceptance rate: 100 / 453 = 2.2075e-01, ESS=7.1241e+01.
# INFO:ABC:t: 3, eps: 49.26274625135194.
# INFO:ABC:Acceptance rate: 100 / 871 = 1.1481e-01, ESS=8.2979e+01.
# INFO:ABC:t: 4, eps: 25.30577574182047.
# INFO:ABC:Acceptance rate: 100 / 1880 = 5.3191e-02, ESS=7.2904e+01.
# INFO:ABC:t: 5, eps: 16.156063886805093.
# INFO:ABC:Acceptance rate: 100 / 3242 = 3.0845e-02, ESS=8.7291e+01.
# INFO:ABC:t: 6, eps: 10.741669440327763.
# INFO:ABC:Acceptance rate: 100 / 6014 = 1.6628e-02, ESS=2.7062e+01.
# INFO:ABC:t: 7, eps: 5.737278539182601.
# INFO:ABC:Acceptance rate: 100 / 18591 = 5.3789e-03, ESS=8.8289e+01.
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=67, duration=0:00:50.674148, end_time=2021-03-25 17:07:17.205330>

# %% [markdown]
# Next, we use adaptive distances but no factors:

# %%
distance = pyabc.AdaptivePNormDistance(p=1, )#factors=factors)

abc = pyabc.ABCSMC(model, prior, distance)

db_path = pyabc.create_sqlite_db_id(file_="adaptive_distance.db")
abc.new(db_path, observation)
history2 = abc.run(max_nr_populations=8)

plot_history(history2)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=68, start_time=2021-03-25 17:07:18.864558>
# INFO:ABC:Calibration sample t=-1.
# INFO:Epsilon:initial epsilon is 89.07623517833986
# INFO:Population:Recording also rejected particles: True
# INFO:ABC:t: 0, eps: 89.07623517833986.
# INFO:ABC:Acceptance rate: 100 / 184 = 5.4348e-01, ESS=1.0000e+02.
# INFO:ABC:t: 1, eps: 43.88544136350744.
# INFO:ABC:Acceptance rate: 100 / 264 = 3.7879e-01, ESS=9.0429e+01.
# INFO:ABC:t: 2, eps: 29.94954991654486.
# INFO:ABC:Acceptance rate: 100 / 409 = 2.4450e-01, ESS=8.9011e+01.
# INFO:ABC:t: 3, eps: 18.015628307273953.
# INFO:ABC:Acceptance rate: 100 / 652 = 1.5337e-01, ESS=8.0470e+01.
# INFO:ABC:t: 4, eps: 10.492226468024203.
# INFO:ABC:Acceptance rate: 100 / 1132 = 8.8339e-02, ESS=8.8549e+01.
# INFO:ABC:t: 5, eps: 5.761032033073994.
# INFO:ABC:Acceptance rate: 100 / 2448 = 4.0850e-02, ESS=2.8295e+01.
# INFO:ABC:t: 6, eps: 4.2783485607315.
# INFO:ABC:Acceptance rate: 100 / 5104 = 1.9592e-02, ESS=9.3206e+01.
# INFO:ABC:t: 7, eps: 2.390615663154861.
# INFO:ABC:Acceptance rate: 100 / 6798 = 1.4710e-02, ESS=5.8825e+01.
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=68, duration=0:00:42.535093, end_time=2021-03-25 17:08:01.399651>

# %% [markdown]
# Next, we account for the discrepancy in data point counts by using self-defined scaling factors:

# %%
factors = {}
for j in range(N0):
    factors['p0_' + str(j)] = 1/N0
for j in range(N1):
    factors['p1_' + str(j)] = 1/N1
distance = pyabc.PNormDistance(p=1, factors=factors)

abc = pyabc.ABCSMC(model, prior, distance)

db_path = pyabc.create_sqlite_db_id(file_="adaptive_distance.db")
abc.new(db_path, observation)
history3 = abc.run(max_nr_populations=8)

plot_history(history3)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=17, start_time=2021-02-23 23:27:49.624905>
# INFO:ABC:Calibration sample t=-1.
# INFO:Epsilon:initial epsilon is 9.69873617254857
# INFO:ABC:t: 0, eps: 9.69873617254857.
# INFO:ABC:Acceptance rate: 100 / 223 = 4.4843e-01, ESS=1.0000e+02.
# INFO:ABC:t: 1, eps: 6.9336230863246.
# INFO:ABC:Acceptance rate: 100 / 186 = 5.3763e-01, ESS=9.2707e+01.
# INFO:ABC:t: 2, eps: 4.972662295358695.
# INFO:ABC:Acceptance rate: 100 / 238 = 4.2017e-01, ESS=9.0912e+01.
# INFO:ABC:t: 3, eps: 3.1228552685872213.
# INFO:ABC:Acceptance rate: 100 / 319 = 3.1348e-01, ESS=8.9506e+01.
# INFO:ABC:t: 4, eps: 2.257091180857255.
# INFO:ABC:Acceptance rate: 100 / 348 = 2.8736e-01, ESS=9.0875e+01.
# INFO:ABC:t: 5, eps: 1.2888874486688884.
# INFO:ABC:Acceptance rate: 100 / 634 = 1.5773e-01, ESS=6.6441e+01.
# INFO:ABC:t: 6, eps: 0.991873966618299.
# INFO:ABC:Acceptance rate: 100 / 802 = 1.2469e-01, ESS=8.2069e+01.
# INFO:ABC:t: 7, eps: 0.6457035409335998.
# INFO:ABC:Acceptance rate: 100 / 1231 = 8.1235e-02, ESS=9.0781e+01.
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=17, duration=0:00:35.839710, end_time=2021-02-23 23:28:25.464615>

# %% [markdown]
# Next, we consider automatic weighting and factors:

# %%
import logging
df_logger = logging.getLogger('Distance')
# df_logger.setLevel(logging.DEBUG)

factors = {}
for j in range(N0):
    factors['p0_' + str(j)] = 1/N0
for j in range(N1):
    factors['p1_' + str(j)] = 1/N1
distance = pyabc.AdaptivePNormDistance(p=1, factors=factors)

abc = pyabc.ABCSMC(model, prior, distance)

db_path = pyabc.create_sqlite_db_id(file_="adaptive_distance.db")
abc.new(db_path, observation)
history4 = abc.run(max_nr_populations=8)

plot_history(history4)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=86, start_time=2021-02-24 15:14:55.260471>
# INFO:ABC:Calibration sample t=-1.
# INFO:Epsilon:initial epsilon is 11.441447753468044
# INFO:ABC:t: 0, eps: 11.441447753468044.
# INFO:ABC:Acceptance rate: 100 / 229 = 4.3668e-01, ESS=1.0000e+02.
# INFO:ABC:t: 1, eps: 6.748100063212861.
# INFO:ABC:Acceptance rate: 100 / 260 = 3.8462e-01, ESS=9.1216e+01.
# INFO:ABC:t: 2, eps: 4.56042625974197.
# INFO:ABC:Acceptance rate: 100 / 231 = 4.3290e-01, ESS=9.1521e+01.
# INFO:ABC:t: 3, eps: 3.503358803928611.
# INFO:ABC:Acceptance rate: 100 / 232 = 4.3103e-01, ESS=9.4152e+01.
# INFO:ABC:t: 4, eps: 2.590125956577517.
# INFO:ABC:Acceptance rate: 100 / 364 = 2.7473e-01, ESS=8.8304e+01.
# INFO:ABC:t: 5, eps: 2.3091896687534055.
# INFO:ABC:Acceptance rate: 100 / 413 = 2.4213e-01, ESS=8.0698e+01.
# INFO:ABC:t: 6, eps: 2.0774322459504635.
# INFO:ABC:Acceptance rate: 100 / 504 = 1.9841e-01, ESS=8.6680e+01.
# INFO:ABC:t: 7, eps: 1.675105789289944.
# INFO:ABC:Acceptance rate: 100 / 482 = 2.0747e-01, ESS=7.7776e+01.
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=86, duration=0:00:31.302482, end_time=2021-02-24 15:15:26.562953>

# %%
import logging
df_logger = logging.getLogger('Distance')
# df_logger.setLevel(logging.DEBUG)

from sklearn.linear_model import LinearRegression

distance = pyabc.distance.InfoWeightedPNormDistance(predictor=LinearRegression(fit_intercept=False, normalize=False))

abc = pyabc.ABCSMC(model, prior, distance)

db_path = pyabc.create_sqlite_db_id(file_="adaptive_distance.db")
abc.new(db_path, observation)
history52 = abc.run(max_nr_populations=8)

plot_history(history52)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=71, start_time=2021-03-25 17:10:59.686479>
# INFO:ABC:Calibration sample t=-1.
# DEBUG:Distance:Weights[0] = {'p0_0': 0.9692140477890215, 'p0_1': 0.0284823930882217, 'p0_2': 0.010526315788860518, 'p0_3': 0.010526315788860518, 'p0_4': 0.010526315788860518, 'p0_5': 0.010526315788860518, 'p0_6': 0.010526315788860518, 'p0_7': 0.010526315788860518, 'p0_8': 0.010526315788860518, 'p0_9': 0.010526315788860518, 'p0_10': 0.010526315788860518, 'p0_11': 0.010526315788860518, 'p0_12': 0.010526315788860518, 'p0_13': 0.010526315788860518, 'p0_14': 0.010526315788860518, 'p0_15': 0.010526315788860518, 'p0_16': 0.010526315788860518, 'p0_17': 0.010526315788860518, 'p0_18': 0.010526315788860518, 'p0_19': 0.010526315788860518, 'p0_20': 0.010526315788860518, 'p0_21': 0.010526315788860518, 'p0_22': 0.010526315788860518, 'p0_23': 0.010526315788860518, 'p0_24': 0.010526315788860518, 'p0_25': 0.0007678530216101633, 'p0_26': 0.010526315788860518, 'p0_27': 0.010526315788860518, 'p0_28': 0.010526315788860518, 'p0_29': 0.010526315788860518, 'p0_30': 0.010526315788860518, 'p0_31': 0.010526315788860518, 'p0_32': 0.010526315788860518, 'p0_33': 0.010526315788860518, 'p0_34': 0.010526315788860518, 'p0_35': 0.010526315788869697, 'p0_36': 0.010526315788860518, 'p0_37': 0.010526315788869697, 'p0_38': 0.010526315788860518, 'p0_39': 0.010526315788869697, 'p0_40': 0.010526315788860518, 'p0_41': 0.010526315788869697, 'p0_42': 0.010526315788860518, 'p0_43': 0.010526315788869697, 'p0_44': 0.010526315788860518, 'p0_45': 0.010526315788869697, 'p0_46': 0.010526315788860518, 'p0_47': 0.010526315788869697, 'p0_48': 0.010526315788860518, 'p0_49': 0.010526315788869697, 'p0_50': 0.0007678530216009856, 'p0_51': 0.010526315788869697, 'p0_52': 0.010526315788860518, 'p0_53': 0.010526315788869697, 'p0_54': 0.010526315788860518, 'p0_55': 0.010526315788860518, 'p0_56': 0.010526315788860518, 'p0_57': 0.010526315788869697, 'p0_58': 0.010526315788860518, 'p0_59': 0.010526315788869697, 'p0_60': 0.010526315788860518, 'p0_61': 0.010526315788869697, 'p0_62': 0.010526315788860518, 'p0_63': 0.010526315788869697, 'p0_64': 0.010526315788860518, 'p0_65': 0.010526315788847575, 'p0_66': 0.010526315788860518, 'p0_67': 0.010526315788869697, 'p0_68': 0.010526315788860518, 'p0_69': 0.010526315788869697, 'p0_70': 0.010526315788860518, 'p0_71': 0.010526315788869697, 'p0_72': 0.010526315788860518, 'p0_73': 0.010526315788869697, 'p0_74': 0.010526315788860518, 'p0_75': 0.0007678530215880432, 'p0_76': 0.010526315788860518, 'p0_77': 0.010526315788869697, 'p0_78': 0.010526315788838399, 'p0_79': 0.010526315788869697, 'p0_80': 0.010526315788860518, 'p0_81': 0.010526315788869697, 'p0_82': 0.010526315788860518, 'p0_83': 0.010526315788869697, 'p0_84': 0.010526315788860518, 'p0_85': 0.010526315788869697, 'p0_86': 0.010526315788860518, 'p0_87': 0.010526315788869697, 'p0_88': 0.010526315788860518, 'p0_89': 0.010526315788869697, 'p0_90': 0.010526315788860518, 'p0_91': 0.010526315788869697, 'p0_92': 0.010526315788860518, 'p0_93': 0.010526315788869697, 'p0_94': 0.010526315788860518, 'p0_95': 0.010526315788869697, 'p0_96': 0.010526315788869697, 'p0_97': 0.010526315788869697, 'p0_98': 0.010526315788858636, 'p0_99': 0.010526315788858636, 'p1_0': 1.1597181495492413e-10}
# INFO:Epsilon:initial epsilon is 4.91197857147883
# INFO:Population:Recording also rejected particles: True
# INFO:ABC:t: 0, eps: 4.91197857147883.
# INFO:ABC:Acceptance rate: 100 / 208 = 4.8077e-01, ESS=1.0000e+02.
# DEBUG:Distance:Weights[1] = {'p0_0': 0.009999934759503736, 'p0_1': 0.009999934759503736, 'p0_2': 0.009999934759503736, 'p0_3': 0.009999934759503736, 'p0_4': 0.009999934759503736, 'p0_5': 0.009999934759503736, 'p0_6': 0.009999934759503736, 'p0_7': 0.009999934759503736, 'p0_8': 0.009999934759503736, 'p0_9': 0.009999934759503736, 'p0_10': 0.009999934759503736, 'p0_11': 0.009999934759503736, 'p0_12': 0.009999934759503736, 'p0_13': 0.009999934759503736, 'p0_14': 0.009999934759503736, 'p0_15': 0.009999934759503736, 'p0_16': 0.009999934759503736, 'p0_17': 0.009999934759503736, 'p0_18': 0.009999934759503736, 'p0_19': 0.009999934759503736, 'p0_20': 0.009999934759503736, 'p0_21': 0.009999934759503736, 'p0_22': 0.009999934759503736, 'p0_23': 0.009999934759503736, 'p0_24': 0.009999934759503736, 'p0_25': 0.009999934759503736, 'p0_26': 0.009999934759503736, 'p0_27': 0.009999934759503736, 'p0_28': 0.009999934759503736, 'p0_29': 0.009999934759503736, 'p0_30': 0.009999934759503736, 'p0_31': 0.009999934759503736, 'p0_32': 0.009999934759503736, 'p0_33': 0.009999934759503736, 'p0_34': 0.009999934759503736, 'p0_35': 0.009999934759503736, 'p0_36': 0.009999934759503736, 'p0_37': 0.009999934759503736, 'p0_38': 0.009999934759503736, 'p0_39': 0.009999934759503736, 'p0_40': 0.009999934759503736, 'p0_41': 0.009999934759503736, 'p0_42': 0.009999934759503736, 'p0_43': 0.009999934759503736, 'p0_44': 0.009999934759503736, 'p0_45': 0.009999934759503736, 'p0_46': 0.009999934759503736, 'p0_47': 0.009999934759503736, 'p0_48': 0.009999934759503736, 'p0_49': 0.009999934759503736, 'p0_50': 0.009999934759503736, 'p0_51': 0.009999934759503736, 'p0_52': 0.009999934759503736, 'p0_53': 0.009999934759503736, 'p0_54': 0.009999934759503736, 'p0_55': 0.009999934759503736, 'p0_56': 0.009999934759503736, 'p0_57': 0.009999934759503736, 'p0_58': 0.009999934759503736, 'p0_59': 0.009999934759503736, 'p0_60': 0.009999934759503736, 'p0_61': 0.009999934759503736, 'p0_62': 0.009999934759503736, 'p0_63': 0.009999934759503736, 'p0_64': 0.009999934759503736, 'p0_65': 0.009999934759503736, 'p0_66': 0.009999934759503736, 'p0_67': 0.009999934759503736, 'p0_68': 0.009999934759503736, 'p0_69': 0.009999934759503736, 'p0_70': 0.009999934759503736, 'p0_71': 0.009999934759503736, 'p0_72': 0.009999934759503736, 'p0_73': 0.009999934759503736, 'p0_74': 0.009999934759503736, 'p0_75': 0.009999934759503736, 'p0_76': 0.009999934759503736, 'p0_77': 0.009999934759503736, 'p0_78': 0.009999934759503736, 'p0_79': 0.009999934759503736, 'p0_80': 0.009999934759503736, 'p0_81': 0.009999934759503736, 'p0_82': 0.009999934759503736, 'p0_83': 0.009999934759503736, 'p0_84': 0.009999934759503736, 'p0_85': 0.009999934759503736, 'p0_86': 0.009999934759503736, 'p0_87': 0.009999934759503736, 'p0_88': 0.009999934759503736, 'p0_89': 0.009999934759503736, 'p0_90': 0.009999934759503736, 'p0_91': 0.009999934759503736, 'p0_92': 0.009999934759503736, 'p0_93': 0.009999934759503736, 'p0_94': 0.009999934759503736, 'p0_95': 0.009999934759503736, 'p0_96': 0.009999934759503736, 'p0_97': 0.009999934759503736, 'p0_98': 0.009999934759503736, 'p0_99': 0.009999934759503736, 'p1_0': 1.0000065240496263}
# INFO:ABC:t: 1, eps: 5.195819537314496.
# INFO:ABC:Acceptance rate: 100 / 168 = 5.9524e-01, ESS=2.8081e+00.
# DEBUG:Distance:Weights[2] = {'p0_0': 0.009638188985269282, 'p0_1': 0.009638188985269282, 'p0_2': 0.009638188985269282, 'p0_3': 0.009638188985269282, 'p0_4': 0.009638188985269282, 'p0_5': 0.009638188985269282, 'p0_6': 0.009638188985269282, 'p0_7': 0.009638188985269282, 'p0_8': 0.009638188985269282, 'p0_9': 0.009638188985269282, 'p0_10': 0.009638188985269282, 'p0_11': 0.009638188985269282, 'p0_12': 0.009638188985269282, 'p0_13': 0.009638188985269282, 'p0_14': 0.009638188985269282, 'p0_15': 0.009638188985269282, 'p0_16': 0.009638188985269282, 'p0_17': 0.009638188985269282, 'p0_18': 0.009638188985269282, 'p0_19': 0.009638188985269282, 'p0_20': 0.009638188985269282, 'p0_21': 0.009638188985269282, 'p0_22': 0.009638188985269282, 'p0_23': 0.009638188985269282, 'p0_24': 0.009638188985269282, 'p0_25': 0.009638188985269282, 'p0_26': 0.009638188985269282, 'p0_27': 0.009638188985269282, 'p0_28': 0.009638188985269282, 'p0_29': 0.009638188985269282, 'p0_30': 0.009638188985269282, 'p0_31': 0.009638188985269282, 'p0_32': 0.009638188985269282, 'p0_33': 0.009638188985269282, 'p0_34': 0.009638188985269282, 'p0_35': 0.009638188985269282, 'p0_36': 0.009638188985269282, 'p0_37': 0.009638188985269282, 'p0_38': 0.009638188985269282, 'p0_39': 0.009638188985269282, 'p0_40': 0.009638188985269282, 'p0_41': 0.009638188985269282, 'p0_42': 0.009638188985269282, 'p0_43': 0.009638188985269282, 'p0_44': 0.009638188985269282, 'p0_45': 0.009638188985269282, 'p0_46': 0.009638188985269282, 'p0_47': 0.009638188985269282, 'p0_48': 0.009638188985269282, 'p0_49': 0.009638188985269282, 'p0_50': 0.009638188985269282, 'p0_51': 0.009638188985269282, 'p0_52': 0.009638188985269282, 'p0_53': 0.009638188985269282, 'p0_54': 0.009638188985269282, 'p0_55': 0.009638188985269282, 'p0_56': 0.009638188985269282, 'p0_57': 0.009638188985269282, 'p0_58': 0.009638188985269282, 'p0_59': 0.009638188985269282, 'p0_60': 0.009638188985269282, 'p0_61': 0.009638188985269282, 'p0_62': 0.009638188985269282, 'p0_63': 0.009638188985269282, 'p0_64': 0.009638188985269282, 'p0_65': 0.009638188985269282, 'p0_66': 0.009638188985269282, 'p0_67': 0.009638188985269282, 'p0_68': 0.009638188985269282, 'p0_69': 0.009638188985269282, 'p0_70': 0.009638188985269282, 'p0_71': 0.009638188985269282, 'p0_72': 0.009638188985269282, 'p0_73': 0.009638188985269282, 'p0_74': 0.009638188985269282, 'p0_75': 0.009638188985269282, 'p0_76': 0.009638188985269282, 'p0_77': 0.009638188985269282, 'p0_78': 0.009638188985269282, 'p0_79': 0.009638188985269282, 'p0_80': 0.009638188985269282, 'p0_81': 0.009638188985269282, 'p0_82': 0.009638188985269282, 'p0_83': 0.009638188985269282, 'p0_84': 0.009638188985269282, 'p0_85': 0.009638188985269282, 'p0_86': 0.009638188985269282, 'p0_87': 0.009638188985269282, 'p0_88': 0.009638188985269282, 'p0_89': 0.009638188985269282, 'p0_90': 0.009638188985269282, 'p0_91': 0.009638188985269282, 'p0_92': 0.009638188985269282, 'p0_93': 0.009638188985269282, 'p0_94': 0.009638188985269282, 'p0_95': 0.009638188985269282, 'p0_96': 0.009638188985269282, 'p0_97': 0.009638188985269282, 'p0_98': 0.009638188985269282, 'p0_99': 0.009638188985269282, 'p1_0': 1.0361811014730717}
# INFO:ABC:t: 2, eps: 2.5550284900310167.
# INFO:ABC:Acceptance rate: 100 / 209 = 4.7847e-01, ESS=6.8395e+01.
# DEBUG:Distance:Weights[3] = {'p0_0': 0.009043239015100138, 'p0_1': 0.009043239015100138, 'p0_2': 0.009043239015100138, 'p0_3': 0.009043239015100138, 'p0_4': 0.009043239015100138, 'p0_5': 0.009043239015100138, 'p0_6': 0.009043239015100138, 'p0_7': 0.009043239015100138, 'p0_8': 0.009043239015100138, 'p0_9': 0.009043239015100138, 'p0_10': 0.009043239015100138, 'p0_11': 0.009043239015100138, 'p0_12': 0.009043239015100138, 'p0_13': 0.009043239015100138, 'p0_14': 0.009043239015100138, 'p0_15': 0.009043239015100138, 'p0_16': 0.009043239015100138, 'p0_17': 0.009043239015100138, 'p0_18': 0.009043239015100138, 'p0_19': 0.009043239015100138, 'p0_20': 0.009043239015100138, 'p0_21': 0.009043239015100138, 'p0_22': 0.009043239015100138, 'p0_23': 0.009043239015100138, 'p0_24': 0.009043239015100138, 'p0_25': 0.009043239015100138, 'p0_26': 0.009043239015100138, 'p0_27': 0.009043239015100138, 'p0_28': 0.009043239015100138, 'p0_29': 0.009043239015100138, 'p0_30': 0.009043239015100138, 'p0_31': 0.009043239015100138, 'p0_32': 0.009043239015100138, 'p0_33': 0.009043239015100138, 'p0_34': 0.009043239015100138, 'p0_35': 0.009043239015100138, 'p0_36': 0.009043239015100138, 'p0_37': 0.009043239015100138, 'p0_38': 0.009043239015100138, 'p0_39': 0.009043239015100138, 'p0_40': 0.009043239015100138, 'p0_41': 0.009043239015100138, 'p0_42': 0.009043239015100138, 'p0_43': 0.009043239015100138, 'p0_44': 0.009043239015100138, 'p0_45': 0.009043239015100138, 'p0_46': 0.009043239015100138, 'p0_47': 0.009043239015100138, 'p0_48': 0.009043239015100138, 'p0_49': 0.009043239015100138, 'p0_50': 0.009043239015100138, 'p0_51': 0.009043239015100138, 'p0_52': 0.009043239015100138, 'p0_53': 0.009043239015100138, 'p0_54': 0.009043239015100138, 'p0_55': 0.009043239015100138, 'p0_56': 0.009043239015100138, 'p0_57': 0.009043239015100138, 'p0_58': 0.009043239015100138, 'p0_59': 0.009043239015100138, 'p0_60': 0.009043239015100138, 'p0_61': 0.009043239015100138, 'p0_62': 0.009043239015100138, 'p0_63': 0.009043239015100138, 'p0_64': 0.009043239015100138, 'p0_65': 0.009043239015100138, 'p0_66': 0.009043239015100138, 'p0_67': 0.009043239015100138, 'p0_68': 0.009043239015100138, 'p0_69': 0.009043239015100138, 'p0_70': 0.009043239015100138, 'p0_71': 0.009043239015100138, 'p0_72': 0.009043239015100138, 'p0_73': 0.009043239015100138, 'p0_74': 0.009043239015100138, 'p0_75': 0.009043239015100138, 'p0_76': 0.009043239015100138, 'p0_77': 0.009043239015100138, 'p0_78': 0.009043239015100138, 'p0_79': 0.009043239015100138, 'p0_80': 0.009043239015100138, 'p0_81': 0.009043239015100138, 'p0_82': 0.009043239015100138, 'p0_83': 0.009043239015100138, 'p0_84': 0.009043239015100138, 'p0_85': 0.009043239015100138, 'p0_86': 0.009043239015100138, 'p0_87': 0.009043239015100138, 'p0_88': 0.009043239015100138, 'p0_89': 0.009043239015100138, 'p0_90': 0.009043239015100138, 'p0_91': 0.009043239015100138, 'p0_92': 0.009043239015100138, 'p0_93': 0.009043239015100138, 'p0_94': 0.009043239015100138, 'p0_95': 0.009043239015100138, 'p0_96': 0.009043239015100138, 'p0_97': 0.009043239015100138, 'p0_98': 0.009043239015100138, 'p0_99': 0.009043239015100138, 'p1_0': 1.0956760984899863}
# INFO:ABC:t: 3, eps: 1.6033952589368576.
# INFO:ABC:Acceptance rate: 100 / 173 = 5.7803e-01, ESS=9.3710e+01.
# DEBUG:Distance:Weights[4] = {'p0_0': 0.009856320751455285, 'p0_1': 0.009856320751502378, 'p0_2': 0.009856320751455285, 'p0_3': 0.009856320751502378, 'p0_4': 0.009856320751455285, 'p0_5': 0.009856320751502378, 'p0_6': 0.009856320751455285, 'p0_7': 0.009856320751502378, 'p0_8': 0.009856320751455285, 'p0_9': 0.009856320751502378, 'p0_10': 0.009856320751455285, 'p0_11': 0.009856320751502378, 'p0_12': 0.009856320751455285, 'p0_13': 0.009856320751502378, 'p0_14': 0.009856320751455285, 'p0_15': 0.009856320751502378, 'p0_16': 0.009856320751455285, 'p0_17': 0.009856320751502378, 'p0_18': 0.009856320751455285, 'p0_19': 0.009856320751502378, 'p0_20': 0.009856320751455285, 'p0_21': 0.009856320751502378, 'p0_22': 0.009856320751455285, 'p0_23': 0.009856320751502378, 'p0_24': 0.009856320751455285, 'p0_25': 0.009856320751502378, 'p0_26': 0.009856320751455285, 'p0_27': 0.009856320751502378, 'p0_28': 0.009856320751455285, 'p0_29': 0.009856320751502378, 'p0_30': 0.009856320751455285, 'p0_31': 0.009856320751502378, 'p0_32': 0.009856320751455285, 'p0_33': 0.009856320751502378, 'p0_34': 0.009856320751455285, 'p0_35': 0.009856320751502378, 'p0_36': 0.009856320751455285, 'p0_37': 0.009856320751502378, 'p0_38': 0.009856320751455285, 'p0_39': 0.009856320751502378, 'p0_40': 0.009856320751455285, 'p0_41': 0.009856320751502378, 'p0_42': 0.009856320751455285, 'p0_43': 0.009856320751502378, 'p0_44': 0.009856320751455285, 'p0_45': 0.009856320751502378, 'p0_46': 0.009856320751455285, 'p0_47': 0.009856320751502378, 'p0_48': 0.009856320751455285, 'p0_49': 0.009856320751502378, 'p0_50': 0.009856320751455285, 'p0_51': 0.009856320751502378, 'p0_52': 0.009856320751455285, 'p0_53': 0.009856320751502378, 'p0_54': 0.009856320751455285, 'p0_55': 0.009856320751502378, 'p0_56': 0.009856320751455285, 'p0_57': 0.009856320751502378, 'p0_58': 0.009856320751455285, 'p0_59': 0.009856320751502378, 'p0_60': 0.009856320751455285, 'p0_61': 0.009856320751502378, 'p0_62': 0.009856320751455285, 'p0_63': 0.009856320751502378, 'p0_64': 0.009856320751455285, 'p0_65': 0.009856320751455285, 'p0_66': 0.009856320751455285, 'p0_67': 0.009856320751455285, 'p0_68': 0.009856320751455285, 'p0_69': 0.009856320751455285, 'p0_70': 0.009856320751455285, 'p0_71': 0.009856320751455285, 'p0_72': 0.009856320751455285, 'p0_73': 0.009856320751455285, 'p0_74': 0.009856320751455285, 'p0_75': 0.009856320751455285, 'p0_76': 0.009856320751455285, 'p0_77': 0.009856320751455285, 'p0_78': 0.009856320751455285, 'p0_79': 0.009856320751455285, 'p0_80': 0.009856320751455285, 'p0_81': 0.009856320751455285, 'p0_82': 0.009856320751455285, 'p0_83': 0.009856320751455285, 'p0_84': 0.009856320751455285, 'p0_85': 0.009856320751455285, 'p0_86': 0.009856320751455285, 'p0_87': 0.009856320751455285, 'p0_88': 0.009856320751455285, 'p0_89': 0.009856320751455285, 'p0_90': 0.009856320751455285, 'p0_91': 0.009856320751455285, 'p0_92': 0.009856320751455285, 'p0_93': 0.009856320751455285, 'p0_94': 0.009856320751455285, 'p0_95': 0.009856320751455285, 'p0_96': 0.009856320751455285, 'p0_97': 0.009856320751455285, 'p0_98': 0.009856320751455285, 'p0_99': 0.009856320751455285, 'p1_0': 1.0143679248529645}
# INFO:ABC:t: 4, eps: 0.8954007563332157.
# INFO:ABC:Acceptance rate: 100 / 210 = 4.7619e-01, ESS=9.3653e+01.
# DEBUG:Distance:Weights[5] = {'p0_0': 0.009670257354677685, 'p0_1': 0.009670257354723887, 'p0_2': 0.009670257354677685, 'p0_3': 0.009670257354723887, 'p0_4': 0.009670257354677685, 'p0_5': 0.009670257354723887, 'p0_6': 0.009670257354677685, 'p0_7': 0.009670257354723887, 'p0_8': 0.009670257354677685, 'p0_9': 0.009670257354723887, 'p0_10': 0.009670257354677685, 'p0_11': 0.009670257354723887, 'p0_12': 0.009670257354677685, 'p0_13': 0.009670257354723887, 'p0_14': 0.009670257354677685, 'p0_15': 0.009670257354723887, 'p0_16': 0.009670257354677685, 'p0_17': 0.009670257354723887, 'p0_18': 0.009670257354677685, 'p0_19': 0.009670257354723887, 'p0_20': 0.009670257354677685, 'p0_21': 0.009670257354723887, 'p0_22': 0.009670257354677685, 'p0_23': 0.009670257354723887, 'p0_24': 0.009670257354677685, 'p0_25': 0.009670257354723887, 'p0_26': 0.009670257354677685, 'p0_27': 0.009670257354723887, 'p0_28': 0.009670257354677685, 'p0_29': 0.009670257354723887, 'p0_30': 0.009670257354677685, 'p0_31': 0.009670257354723887, 'p0_32': 0.009670257354677685, 'p0_33': 0.009670257354723887, 'p0_34': 0.009670257354677685, 'p0_35': 0.009670257354723887, 'p0_36': 0.009670257354677685, 'p0_37': 0.009670257354723887, 'p0_38': 0.009670257354677685, 'p0_39': 0.009670257354723887, 'p0_40': 0.009670257354677685, 'p0_41': 0.009670257354723887, 'p0_42': 0.009670257354677685, 'p0_43': 0.009670257354723887, 'p0_44': 0.009670257354677685, 'p0_45': 0.009670257354723887, 'p0_46': 0.009670257354677685, 'p0_47': 0.009670257354723887, 'p0_48': 0.009670257354677685, 'p0_49': 0.009670257354723887, 'p0_50': 0.009670257354677685, 'p0_51': 0.009670257354723887, 'p0_52': 0.009670257354677685, 'p0_53': 0.009670257354723887, 'p0_54': 0.009670257354677685, 'p0_55': 0.009670257354723887, 'p0_56': 0.009670257354677685, 'p0_57': 0.009670257354723887, 'p0_58': 0.009670257354677685, 'p0_59': 0.009670257354723887, 'p0_60': 0.009670257354677685, 'p0_61': 0.009670257354723887, 'p0_62': 0.009670257354677685, 'p0_63': 0.009670257354723887, 'p0_64': 0.009670257354677685, 'p0_65': 0.009670257354677685, 'p0_66': 0.009670257354677685, 'p0_67': 0.009670257354677685, 'p0_68': 0.009670257354677685, 'p0_69': 0.009670257354677685, 'p0_70': 0.009670257354677685, 'p0_71': 0.009670257354677685, 'p0_72': 0.009670257354677685, 'p0_73': 0.009670257354677685, 'p0_74': 0.009670257354677685, 'p0_75': 0.009670257354677685, 'p0_76': 0.009670257354677685, 'p0_77': 0.009670257354677685, 'p0_78': 0.009670257354677685, 'p0_79': 0.009670257354677685, 'p0_80': 0.009670257354677685, 'p0_81': 0.009670257354677685, 'p0_82': 0.009670257354677685, 'p0_83': 0.009670257354677685, 'p0_84': 0.009670257354677685, 'p0_85': 0.009670257354677685, 'p0_86': 0.009670257354677685, 'p0_87': 0.009670257354677685, 'p0_88': 0.009670257354677685, 'p0_89': 0.009670257354677685, 'p0_90': 0.009670257354677685, 'p0_91': 0.009670257354677685, 'p0_92': 0.009670257354677685, 'p0_93': 0.009670257354677685, 'p0_94': 0.009670257354677685, 'p0_95': 0.009670257354677685, 'p0_96': 0.009670257354677685, 'p0_97': 0.009670257354677685, 'p0_98': 0.009670257354677685, 'p0_99': 0.009670257354677685, 'p1_0': 1.0329742645307531}
# INFO:ABC:t: 5, eps: 0.6039156806139964.
# INFO:ABC:Acceptance rate: 100 / 208 = 4.8077e-01, ESS=9.0265e+01.
# DEBUG:Distance:Weights[6] = {'p0_0': 0.00983046617951872, 'p0_1': 0.00983046617951872, 'p0_2': 0.00983046617951872, 'p0_3': 0.00983046617951872, 'p0_4': 0.00983046617951872, 'p0_5': 0.00983046617951872, 'p0_6': 0.00983046617951872, 'p0_7': 0.00983046617951872, 'p0_8': 0.00983046617951872, 'p0_9': 0.00983046617951872, 'p0_10': 0.00983046617951872, 'p0_11': 0.00983046617951872, 'p0_12': 0.00983046617951872, 'p0_13': 0.00983046617951872, 'p0_14': 0.00983046617951872, 'p0_15': 0.00983046617951872, 'p0_16': 0.00983046617951872, 'p0_17': 0.00983046617951872, 'p0_18': 0.00983046617951872, 'p0_19': 0.00983046617951872, 'p0_20': 0.00983046617951872, 'p0_21': 0.00983046617951872, 'p0_22': 0.00983046617951872, 'p0_23': 0.00983046617951872, 'p0_24': 0.00983046617951872, 'p0_25': 0.00983046617951872, 'p0_26': 0.00983046617951872, 'p0_27': 0.00983046617951872, 'p0_28': 0.00983046617951872, 'p0_29': 0.00983046617951872, 'p0_30': 0.00983046617951872, 'p0_31': 0.00983046617951872, 'p0_32': 0.00983046617951872, 'p0_33': 0.00983046617951872, 'p0_34': 0.00983046617951872, 'p0_35': 0.00983046617951872, 'p0_36': 0.00983046617951872, 'p0_37': 0.00983046617951872, 'p0_38': 0.00983046617951872, 'p0_39': 0.00983046617951872, 'p0_40': 0.00983046617951872, 'p0_41': 0.00983046617951872, 'p0_42': 0.00983046617951872, 'p0_43': 0.00983046617951872, 'p0_44': 0.00983046617951872, 'p0_45': 0.00983046617951872, 'p0_46': 0.00983046617951872, 'p0_47': 0.00983046617951872, 'p0_48': 0.00983046617951872, 'p0_49': 0.00983046617951872, 'p0_50': 0.00983046617951872, 'p0_51': 0.00983046617951872, 'p0_52': 0.00983046617951872, 'p0_53': 0.00983046617951872, 'p0_54': 0.00983046617951872, 'p0_55': 0.00983046617951872, 'p0_56': 0.00983046617951872, 'p0_57': 0.00983046617951872, 'p0_58': 0.00983046617951872, 'p0_59': 0.00983046617951872, 'p0_60': 0.00983046617951872, 'p0_61': 0.00983046617951872, 'p0_62': 0.00983046617951872, 'p0_63': 0.00983046617951872, 'p0_64': 0.00983046617951872, 'p0_65': 0.00983046617951872, 'p0_66': 0.00983046617951872, 'p0_67': 0.00983046617951872, 'p0_68': 0.00983046617951872, 'p0_69': 0.00983046617951872, 'p0_70': 0.00983046617951872, 'p0_71': 0.00983046617951872, 'p0_72': 0.00983046617951872, 'p0_73': 0.00983046617951872, 'p0_74': 0.00983046617951872, 'p0_75': 0.00983046617951872, 'p0_76': 0.00983046617951872, 'p0_77': 0.00983046617951872, 'p0_78': 0.00983046617951872, 'p0_79': 0.00983046617951872, 'p0_80': 0.00983046617951872, 'p0_81': 0.00983046617951872, 'p0_82': 0.00983046617951872, 'p0_83': 0.00983046617951872, 'p0_84': 0.00983046617951872, 'p0_85': 0.00983046617951872, 'p0_86': 0.00983046617951872, 'p0_87': 0.00983046617951872, 'p0_88': 0.00983046617951872, 'p0_89': 0.00983046617951872, 'p0_90': 0.00983046617951872, 'p0_91': 0.00983046617951872, 'p0_92': 0.00983046617951872, 'p0_93': 0.00983046617951872, 'p0_94': 0.00983046617951872, 'p0_95': 0.00983046617951872, 'p0_96': 0.00983046617951872, 'p0_97': 0.00983046617951872, 'p0_98': 0.00983046617951872, 'p0_99': 0.00983046617951872, 'p1_0': 1.016953382048128}
# INFO:ABC:t: 6, eps: 0.4366346131043291.
# INFO:ABC:Acceptance rate: 100 / 257 = 3.8911e-01, ESS=9.5458e+01.
# DEBUG:Distance:Weights[7] = {'p0_0': 0.009528891030291151, 'p0_1': 0.009528891030291151, 'p0_2': 0.009528891030291151, 'p0_3': 0.009528891030291151, 'p0_4': 0.009528891030291151, 'p0_5': 0.009528891030291151, 'p0_6': 0.009528891030291151, 'p0_7': 0.009528891030291151, 'p0_8': 0.009528891030291151, 'p0_9': 0.009528891030291151, 'p0_10': 0.009528891030291151, 'p0_11': 0.009528891030291151, 'p0_12': 0.009528891030291151, 'p0_13': 0.009528891030291151, 'p0_14': 0.009528891030291151, 'p0_15': 0.009528891030291151, 'p0_16': 0.009528891030291151, 'p0_17': 0.009528891030291151, 'p0_18': 0.009528891030291151, 'p0_19': 0.009528891030291151, 'p0_20': 0.009528891030291151, 'p0_21': 0.009528891030291151, 'p0_22': 0.009528891030291151, 'p0_23': 0.009528891030291151, 'p0_24': 0.009528891030291151, 'p0_25': 0.009528891030291151, 'p0_26': 0.009528891030291151, 'p0_27': 0.009528891030291151, 'p0_28': 0.009528891030291151, 'p0_29': 0.009528891030291151, 'p0_30': 0.009528891030291151, 'p0_31': 0.009528891030291151, 'p0_32': 0.009528891030291151, 'p0_33': 0.009528891030291151, 'p0_34': 0.009528891030291151, 'p0_35': 0.009528891030291151, 'p0_36': 0.009528891030291151, 'p0_37': 0.009528891030291151, 'p0_38': 0.009528891030291151, 'p0_39': 0.009528891030291151, 'p0_40': 0.009528891030291151, 'p0_41': 0.009528891030291151, 'p0_42': 0.009528891030291151, 'p0_43': 0.009528891030291151, 'p0_44': 0.009528891030291151, 'p0_45': 0.009528891030291151, 'p0_46': 0.009528891030291151, 'p0_47': 0.009528891030291151, 'p0_48': 0.009528891030291151, 'p0_49': 0.009528891030291151, 'p0_50': 0.009528891030291151, 'p0_51': 0.009528891030291151, 'p0_52': 0.009528891030291151, 'p0_53': 0.009528891030291151, 'p0_54': 0.009528891030291151, 'p0_55': 0.009528891030291151, 'p0_56': 0.009528891030291151, 'p0_57': 0.009528891030291151, 'p0_58': 0.009528891030291151, 'p0_59': 0.009528891030291151, 'p0_60': 0.009528891030291151, 'p0_61': 0.009528891030291151, 'p0_62': 0.009528891030291151, 'p0_63': 0.009528891030291151, 'p0_64': 0.009528891030291151, 'p0_65': 0.009528891030291151, 'p0_66': 0.009528891030291151, 'p0_67': 0.009528891030291151, 'p0_68': 0.009528891030291151, 'p0_69': 0.009528891030291151, 'p0_70': 0.009528891030291151, 'p0_71': 0.009528891030291151, 'p0_72': 0.009528891030291151, 'p0_73': 0.009528891030291151, 'p0_74': 0.009528891030291151, 'p0_75': 0.009528891030291151, 'p0_76': 0.009528891030291151, 'p0_77': 0.009528891030291151, 'p0_78': 0.009528891030291151, 'p0_79': 0.009528891030291151, 'p0_80': 0.009528891030291151, 'p0_81': 0.009528891030291151, 'p0_82': 0.009528891030291151, 'p0_83': 0.009528891030291151, 'p0_84': 0.009528891030291151, 'p0_85': 0.009528891030291151, 'p0_86': 0.009528891030291151, 'p0_87': 0.009528891030291151, 'p0_88': 0.009528891030291151, 'p0_89': 0.009528891030291151, 'p0_90': 0.009528891030291151, 'p0_91': 0.009528891030291151, 'p0_92': 0.009528891030291151, 'p0_93': 0.009528891030291151, 'p0_94': 0.009528891030291151, 'p0_95': 0.009528891030291151, 'p0_96': 0.009528891030291151, 'p0_97': 0.009528891030291151, 'p0_98': 0.009528891030291151, 'p0_99': 0.009528891030291151, 'p1_0': 1.0471108969708849}
# INFO:ABC:t: 7, eps: 0.3086083908865079.
# INFO:ABC:Acceptance rate: 100 / 311 = 3.2154e-01, ESS=9.7636e+01.
# DEBUG:Distance:Weights[8] = {'p0_0': 0.00951550302070079, 'p0_1': 0.00951550302070079, 'p0_2': 0.00951550302070079, 'p0_3': 0.00951550302070079, 'p0_4': 0.00951550302070079, 'p0_5': 0.00951550302070079, 'p0_6': 0.00951550302070079, 'p0_7': 0.00951550302070079, 'p0_8': 0.009515503020750162, 'p0_9': 0.00951550302070079, 'p0_10': 0.009515503020750162, 'p0_11': 0.00951550302070079, 'p0_12': 0.009515503020750162, 'p0_13': 0.00951550302070079, 'p0_14': 0.009515503020750162, 'p0_15': 0.00951550302070079, 'p0_16': 0.009515503020750162, 'p0_17': 0.00951550302070079, 'p0_18': 0.009515503020750162, 'p0_19': 0.00951550302070079, 'p0_20': 0.009515503020750162, 'p0_21': 0.00951550302070079, 'p0_22': 0.009515503020750162, 'p0_23': 0.00951550302070079, 'p0_24': 0.009515503020750162, 'p0_25': 0.00951550302070079, 'p0_26': 0.009515503020750162, 'p0_27': 0.00951550302070079, 'p0_28': 0.009515503020750162, 'p0_29': 0.00951550302070079, 'p0_30': 0.009515503020750162, 'p0_31': 0.00951550302070079, 'p0_32': 0.009515503020750162, 'p0_33': 0.00951550302070079, 'p0_34': 0.00951550302070079, 'p0_35': 0.00951550302070079, 'p0_36': 0.00951550302070079, 'p0_37': 0.00951550302070079, 'p0_38': 0.00951550302070079, 'p0_39': 0.00951550302070079, 'p0_40': 0.00951550302070079, 'p0_41': 0.00951550302070079, 'p0_42': 0.00951550302070079, 'p0_43': 0.00951550302070079, 'p0_44': 0.00951550302070079, 'p0_45': 0.00951550302070079, 'p0_46': 0.00951550302070079, 'p0_47': 0.00951550302070079, 'p0_48': 0.00951550302070079, 'p0_49': 0.00951550302070079, 'p0_50': 0.00951550302070079, 'p0_51': 0.00951550302070079, 'p0_52': 0.00951550302070079, 'p0_53': 0.00951550302070079, 'p0_54': 0.00951550302070079, 'p0_55': 0.00951550302070079, 'p0_56': 0.00951550302070079, 'p0_57': 0.00951550302070079, 'p0_58': 0.00951550302070079, 'p0_59': 0.00951550302070079, 'p0_60': 0.00951550302070079, 'p0_61': 0.00951550302070079, 'p0_62': 0.00951550302070079, 'p0_63': 0.00951550302070079, 'p0_64': 0.00951550302070079, 'p0_65': 0.00951550302070079, 'p0_66': 0.00951550302070079, 'p0_67': 0.00951550302070079, 'p0_68': 0.00951550302070079, 'p0_69': 0.00951550302070079, 'p0_70': 0.00951550302070079, 'p0_71': 0.00951550302070079, 'p0_72': 0.00951550302070079, 'p0_73': 0.00951550302070079, 'p0_74': 0.00951550302070079, 'p0_75': 0.00951550302070079, 'p0_76': 0.00951550302070079, 'p0_77': 0.00951550302070079, 'p0_78': 0.00951550302070079, 'p0_79': 0.00951550302070079, 'p0_80': 0.00951550302070079, 'p0_81': 0.00951550302070079, 'p0_82': 0.00951550302070079, 'p0_83': 0.00951550302070079, 'p0_84': 0.00951550302070079, 'p0_85': 0.00951550302070079, 'p0_86': 0.00951550302070079, 'p0_87': 0.00951550302070079, 'p0_88': 0.00951550302070079, 'p0_89': 0.00951550302070079, 'p0_90': 0.00951550302070079, 'p0_91': 0.00951550302070079, 'p0_92': 0.00951550302070079, 'p0_93': 0.00951550302070079, 'p0_94': 0.00951550302070079, 'p0_95': 0.00951550302070079, 'p0_96': 0.00951550302070079, 'p0_97': 0.00951550302070079, 'p0_98': 0.00951550302070079, 'p0_99': 0.00951550302070079, 'p1_0': 1.0484496979292792}
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=71, duration=0:00:29.084855, end_time=2021-03-25 17:11:28.771334>

# %%
import logging
df_logger = logging.getLogger('Distance')
# df_logger.setLevel(logging.DEBUG)

#distance = pyabc.britney.Euclidean(pyabc.britney.LearnedLinearBritney())
distance = pyabc.AdaptivePNormDistance(sumstat=pyabc.GPPredictorSumstat())

abc = pyabc.ABCSMC(model, prior, distance)

db_path = pyabc.create_sqlite_db_id(file_="adaptive_distance.db")
abc.new(db_path, observation)
history52 = abc.run(max_nr_populations=8)

plot_history(history52)
# Out:
# INFO:Sampler:Parallelizing the sampling on 4 cores.
# INFO:History:Start <ABCSMC id=69, start_time=2021-03-25 17:09:10.729685>
# INFO:ABC:Calibration sample t=-1.
# INFO:Epsilon:initial epsilon is 1.327600261750698
# INFO:Population:Recording also rejected particles: True
# INFO:ABC:t: 0, eps: 1.327600261750698.
# INFO:ABC:Acceptance rate: 100 / 220 = 4.5455e-01, ESS=1.0000e+02.
# INFO:ABC:t: 1, eps: 0.8830096361063074.
# INFO:ABC:Acceptance rate: 100 / 213 = 4.6948e-01, ESS=9.3785e+01.
# INFO:ABC:t: 2, eps: 0.8474546824464524.
# INFO:ABC:Acceptance rate: 100 / 278 = 3.5971e-01, ESS=7.6993e+01.
# INFO:ABC:t: 3, eps: 0.7191758721520568.
# INFO:ABC:Acceptance rate: 100 / 351 = 2.8490e-01, ESS=9.7482e+01.
# INFO:ABC:t: 4, eps: 0.6493406366503112.
# INFO:ABC:Acceptance rate: 100 / 395 = 2.5316e-01, ESS=4.1558e+00.
# INFO:ABC:t: 5, eps: 0.8965453326041121.
# INFO:ABC:Acceptance rate: 100 / 482 = 2.0747e-01, ESS=9.0511e+01.
# INFO:ABC:t: 6, eps: 0.5674751266056206.
# INFO:ABC:Acceptance rate: 100 / 312 = 3.2051e-01, ESS=5.4097e+01.
# INFO:ABC:t: 7, eps: 0.542027281972241.
# INFO:ABC:Acceptance rate: 100 / 500 = 2.0000e-01, ESS=8.7517e+01.
# INFO:pyabc.util:Stopping: maximum number of generations.
# INFO:History:Done <ABCSMC id=69, duration=0:00:36.737387, end_time=2021-03-25 17:09:47.467072>

# %% [markdown]
# The results for the distances that re-factor are best, and in this case fixed and adaptive weights give similar results. In addition to the much better posteriors, the sample numbers are much lower, as the below plots show.

# %%
histories = [history1, history2, history3, history4]
labels = ["Standard", "Adaptive", "Factors", "Adaptive + Factors"]

pyabc.visualization.plot_sample_numbers(histories, labels)
pyabc.visualization.plot_total_sample_numbers(histories, labels, yscale='log10')
pyabc.visualization.plot_effective_sample_sizes(histories, labels)
# Out:
# <AxesSubplot:title={'center':'Effective sample size'}, xlabel='Population index', ylabel='ESS'>
